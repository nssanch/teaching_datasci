# %% [markdown]
# [basic usage](https://matplotlib.org/stable/tutorials/introductory/usage.html)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## A Simple Example

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 3, 2, 4]); #plot some data

# %%
#dir()  ##will give info

# %% [markdown]
# ## Parts of a Figure
# refer to this picture for vocabulary when googling stuff

# %% [markdown]
# ### Figure
# figure contains all the info

# %%
fig = plt.figure() #create an empty figure
fig, ax = plt.subplots() #figure with a single axes
fig, axs = plt.subplots(2,2) #figure with 2x2 grid of Axes

# %% [markdown]
# ### Axes, Axis, and Artist
# * Artist: THings that are visible, including Axes, and Axis
# * Axes: contains region for plotting data, includes 2 or 3 Axis
# * Axes: titles and labels
# * Axis: scale and ticks, ticklabels

# %% [markdown]
# ## Types of inputs to plotting functions

# %%
b = np.matrix([[1,2], [3,4]])
b_asarray = np.array(b) #cast matrix (or other stuff) as an array
b_asarray
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100


fig, ax = plt.subplots(figsize=(5,2.7))
ax.scatter('a', 'b', c = 'c', s = 'd', data = data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b');

# %% [markdown]
# ## Coding Styles
# ### Object-oriented and the pyplot interfaces
# * Explicitly create figures and axes and call mehtods on them
#
# OR
# * Rely on pyplot to handle stuff

# %%
#o-o style
x = np.linspace(0, 2, 100)  # Sample data

fig, ax = plt.subplots(figsize=(5, 2.7)) #need to update before layout is allowe
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic') 
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # y-label
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend();  # Add a legend. uses labels listed earlier

# %%
# pyplot style
x = np.linspace(0, 2, 100)  # Sample data.

plt.figure(figsize=(5, 2.7))
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')   #note: 'xlabel' as opposed to 'set_xlabel'
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend();

# %% [markdown]
# ## Making a helper function
# For methods, or for doing the same plot over and over with new data

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph.
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'});

# %% [markdown]
# ## Styling Artists
# *color, linewidth, linestyle*
# use set_linestyle

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(data2), color='orange', linewidth=2)
l.set_linestyle(':');

# %% [markdown]
# ### Colors
# [colors tutorial](https://matplotlib.org/stable/tutorials/colors/colors.html) where to find the codes

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=50, facecolor='C1', edgecolor='g');

# %% [markdown]
# ### Linewidths, linestyles, markersizes

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(data1, 'o', label='data1')
ax.plot(data2, 'd', label='data2')
ax.plot(data3, 'v', label='data3')
ax.plot(data4, 's', label='data4')
ax.legend();

# %% [markdown]
# ## Labelling plots

# %% [markdown]
# ### Axes labels and text

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots(figsize=(5, 2.7))
# the histogram of the data
n, bins, patches = ax.hist(x, 50, density=1, facecolor='C0', alpha=0.75)

t = ax.set_xlabel('my data', fontsize=14, color='red')

t
ax.set_ylabel('Probability')
ax.set_title('Aardvark lengths\n (not really)')
ax.text(75, .025, r'$\mu=115,\ \sigma=15$')
ax.axis([55, 175, 0, 0.03])
ax.grid(True);

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
t = ax.set_xlabel('my data', fontsize=14, color='red')
t
# Out:
# Text(0.5, 0, 'my data')

# %% [markdown]
# ### Using math expressions in text
# TeX expressions surrounded by dollar signs
# ax.set_title(r'$\sigma_i=15$')

# %%
## type '\gamma' then press tab for greek

# %% [markdown]
# ### Annotations

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line, = ax.plot(t, s, lw=2)
                                      #location of text, but there are other options to do this
ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05))  #shink is length

ax.set_ylim(-2, 2);

# %% [markdown]
# ### Legends

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(np.arange(len(data1)), data1, label='data1')
ax.plot(np.arange(len(data2)), data2, label='data2')
ax.plot(np.arange(len(data3)), data3, 'd', label='data3')
ax.legend();

# %% [markdown]
# ## Axis scales and ticks
# Axis controls scal and ticks
# ### scales

# %% [markdown]
# easier to log transform you function, but then you don't get nice ticks, but sometimes going straight to log axis works..

# %% [markdown]
# Seaborn is great for a lot of figure making that you *can* make in matplotlib, but do much more easily in Seaborn

# %%
fig, axs = plt.subplots(1, 2, figsize=(5, 2.7))
xdata = np.arange(len(data1))  # make an ordinal for this
data = 10**data1
axs[0].plot(xdata, data)

axs[1].set_yscale('log')
axs[1].plot(xdata, data);

# %% [markdown]
# ### Tick locators and formatters

# %%
fig, axs = plt.subplots(2, 1)
axs[0].plot(xdata, data1)
axs[0].set_title('Automatic ticks')

axs[1].plot(xdata, data1)
axs[1].set_xticks(np.arange(0, 100, 30), ['zero', '30', 'sixty', '90'])
axs[1].set_yticks([-1.5, 0, 1.5])  # note that we don't need to specify labels
axs[1].set_title('Manual ticks');
# Out:
# <ipython-input-41-0970e5d43858>:6: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(0, 100, 30), ['zero', '30', 'sixty', '90'])

# %% [markdown]
# ### Plotting dates and strings

# %%
#dates
fig, ax = plt.subplots(figsize=(5, 2.7))
dates = np.arange(np.datetime64('2021-11-15'), np.datetime64('2021-12-25'),
                  np.timedelta64(1, 'h'))
data = np.cumsum(np.random.randn(len(dates)))
ax.plot(dates, data)
cdf = mpl.dates.ConciseDateFormatter(ax.xaxis.get_major_locator())
ax.xaxis.set_major_formatter(cdf);

# %%
#strings -- need categories with lengths, not a list of strings
fig, ax = plt.subplots(figsize=(5, 2.7))
categories = ['turnips', 'rutabaga', 'cucumber', 'pumpkins']

ax.bar(categories, np.random.rand(len(categories)));

# %% [markdown]
# ###  Additional Axis objects

# %%
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(8, 2.7))
l1, = ax1.plot(t, s)
ax2 = ax1.twinx()
l2, = ax2.plot(t, range(len(t)), 'C1')
ax2.legend([l1, l2], ['Sine (left)', 'Straight (right)'])

ax3.plot(t, s)
ax3.set_xlabel('Angle [°]')
ax4 = ax3.secondary_xaxis('top', functions=(np.rad2deg, np.deg2rad))
ax4.set_xlabel('Angle [rad]')
# Out:
# Text(0.5, 0, 'Angle [rad]')

# %% [markdown]
# ## Color Mapped Data

# %%
X, Y = np.meshgrid(np.linspace(-3, 3, 128), np.linspace(-3, 3, 128))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

fig, axs = plt.subplots(2, 2)
pc = axs[0, 0].pcolormesh(X, Y, Z, vmin=-1, vmax=1, cmap='RdBu_r')
fig.colorbar(pc, ax=axs[0, 0])
axs[0, 0].set_title('pcolormesh()')

co = axs[0, 1].contourf(X, Y, Z, levels=np.linspace(-1.25, 1.25, 11))
fig.colorbar(co, ax=axs[0, 1])
axs[0, 1].set_title('contourf()')

pc = axs[1, 0].imshow(Z**2 * 100, cmap='plasma',
                          norm=mpl.colors.LogNorm(vmin=0.01, vmax=100))
fig.colorbar(pc, ax=axs[1, 0], extend='both')
axs[1, 0].set_title('imshow() with LogNorm()')

pc = axs[1, 1].scatter(data1, data2, c=data3, cmap='RdBu_r')
fig.colorbar(pc, ax=axs[1, 1], extend='both')
axs[1, 1].set_title('scatter()');
# Out:
# <ipython-input-47-0b74676266c6>:5: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pc = axs[0, 0].pcolormesh(X, Y, Z, vmin=-1, vmax=1, cmap='RdBu_r')

# %% [markdown]
# ## Working with multiple figures and axes

# %%
fig, axd = plt.subplot_mosaic([['upleft', 'right'],
                               ['lowleft', 'right']])
axd['upleft'].set_title('upleft')
axd['lowleft'].set_title('lowleft')
axd['right'].set_title('right');
